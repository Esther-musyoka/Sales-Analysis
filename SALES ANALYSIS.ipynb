# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Naibei_jr\Desktop\ANACONDA SCRIPTS/SALES DATA FOR ANALYSIS.xls")

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df.set_index("Row ID").head(2)
# Out:
#               Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#        Customer Name   Segment        Country       City     State  \
# Row ID
# 1        Claire Gute  Consumer  United States  Henderson  Kentucky
# 2        Claire Gute  Consumer  United States  Henderson  Kentucky
#
#         Postal Code Region       Product ID   Category Sub-Category  \
# Row ID
# 1             42420  South  FUR-BO-10001798  Furniture    Bookcases
# 2             42420  South  FUR-CH-10000454  Furniture       Chairs
#
#                                              Product Name   Sales  Quantity  \
# Row ID
# 1                       Bush Somerset Collection Bookcase  261.96         2
# 2       Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#         Discount    Profit
# Row ID
# 1            0.0   41.9136
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df.set_index("Row ID").head(2)
# Out:
#               Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#        Customer Name   Segment        Country       City     State  \
# Row ID
# 1        Claire Gute  Consumer  United States  Henderson  Kentucky
# 2        Claire Gute  Consumer  United States  Henderson  Kentucky
#
#         Postal Code Region       Product ID   Category Sub-Category  \
# Row ID
# 1             42420  South  FUR-BO-10001798  Furniture    Bookcases
# 2             42420  South  FUR-CH-10000454  Furniture       Chairs
#
#                                              Product Name   Sales  Quantity  \
# Row ID
# 1                       Bush Somerset Collection Bookcase  261.96         2
# 2       Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#         Discount    Profit
# Row ID
# 1            0.0   41.9136
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe().T
# Out:
#               count          mean           std       min          25%  \
# Row ID       9994.0   4997.500000   2885.163629     1.000   2499.25000
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Row ID        4997.5000   7495.750   9994.000
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df["Order Date"].dt.strftime("%m-%y").head()
# Out:
# 0    11-16
# 1    11-16
# 2    06-16
# 3    10-15
# 4    10-15
# Name: Order Date, dtype: object

# %%
df["Order Year"]=pd.to_datetime(df["Order Date"]).dt.year

# %%
df["Order Month"]=pd.to_datetime(df["Order Date"]).dt.month

# %%
df["Ship Year"]=pd.to_datetime(df["Ship Date"]).dt.year

# %%
df["Ship Month"]=pd.to_datetime(df["Ship Date"]).dt.month

# %%
df["Order Day"]=pd.to_datetime(df["Order Date"]).dt.day

# %%
df["Ship Day"]=pd.to_datetime(df["Ship Date"]).dt.day

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Sales  Quantity  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  261.96         2
# 1   Claire Gute  Consumer  United States  Henderson  ...  731.94         3
#
#   Discount    Profit Order Year Order Month Ship Year  Ship Month  Order Day  \
# 0      0.0   41.9136       2016          11      2016          11          8
# 1      0.0  219.5820       2016          11      2016          11          8
#
#    Ship Day
# 0        11
# 1        11
#
# [2 rows x 27 columns]

# %%
df["Selling Price"]=(df["Sales"]*df["Quantity"])-df["Discount"]

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Quantity  Discount  \
# 0   Claire Gute  Consumer  United States  Henderson  ...        2       0.0
# 1   Claire Gute  Consumer  United States  Henderson  ...        3       0.0
#
#      Profit Order Year Order Month Ship Year Ship Month  Order Day  Ship Day  \
# 0   41.9136       2016          11      2016         11          8        11
# 1  219.5820       2016          11      2016         11          8        11
#
#    Selling Price
# 0         523.92
# 1        2195.82
#
# [2 rows x 28 columns]

# %%
df["Buying Price"]=df["Selling Price"]-df["Profit"]

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Discount    Profit  \
# 0   Claire Gute  Consumer  United States  Henderson  ...      0.0   41.9136
# 1   Claire Gute  Consumer  United States  Henderson  ...      0.0  219.5820
#
#   Order Year Order Month Ship Year Ship Month Order Day  Ship Day  \
# 0       2016          11      2016         11         8        11
# 1       2016          11      2016         11         8        11
#
#    Selling Price  Buying Price
# 0         523.92      482.0064
# 1        2195.82     1976.2380
#
# [2 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.drop(columns=["Order Date","Ship Date","Customer Name","Country","State","Region","Sub-Category","Product Name","Selling Price","Buying Price","Row ID","Postal Code"]).head(2)
# Out:
#          Order ID     Ship Mode Customer ID   Segment       City  \
# 0  CA-2016-152156  Second Class    CG-12520  Consumer  Henderson
# 1  CA-2016-152156  Second Class    CG-12520  Consumer  Henderson
#
#         Product ID   Category   Sales  Quantity  Discount    Profit  \
# 0  FUR-BO-10001798  Furniture  261.96         2       0.0   41.9136
# 1  FUR-CH-10000454  Furniture  731.94         3       0.0  219.5820
#
#    Order Year  Order Month  Ship Year  Ship Month  Order Day  Ship Day
# 0        2016           11       2016          11          8        11
# 1        2016           11       2016          11          8        11

# %%
df.plot(kind="box",subplots=True,layout=(6,4),figsize=(18,12));

# %%
df.groupby(["Category"])["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Discount    Profit  \
# 0   Claire Gute  Consumer  United States  Henderson  ...      0.0   41.9136
# 1   Claire Gute  Consumer  United States  Henderson  ...      0.0  219.5820
#
#   Order Year Order Month Ship Year Ship Month Order Day  Ship Day  \
# 0       2016          11      2016         11         8        11
# 1       2016          11      2016         11         8        11
#
#    Selling Price  Buying Price
# 0         523.92      482.0064
# 1        2195.82     1976.2380
#
# [2 rows x 29 columns]

# %%
df.groupby(["Ship Mode"])["Category"].sum()
# Out:
# Ship Mode
# First Class       TechnologyFurnitureTechnologyOffice SuppliesOf...
# Same Day          Office SuppliesOffice SuppliesOffice SuppliesF...
# Second Class      FurnitureFurnitureOffice SuppliesOffice Suppli...
# Standard Class    FurnitureOffice SuppliesFurnitureOffice Suppli...
# Name: Category, dtype: object
